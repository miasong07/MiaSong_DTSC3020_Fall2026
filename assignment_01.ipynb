# %% [markdown]
# <a href="https://colab.research.google.com/github/miasong07/MiaSong_DTSC3020_Fall2026/blob/main/assignment_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name= "Mia"
print(name)
# Out:
# Mia
